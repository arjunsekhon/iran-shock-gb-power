# %%
import os
from pathlib import Path

ROOT = Path.cwd()
while not (ROOT / "pyproject.toml").exists():
    ROOT = ROOT.parent
os.chdir(ROOT)

# %%
import pandas as pd

from iran_shock.columns import CODE_COLUMNS, EVENT_COLUMNS

df = pd.read_csv(
    "data/raw/20260228120000.export.CSV",
    sep="\t",
    header=None,
    names=EVENT_COLUMNS,
    dtype=dict.fromkeys(CODE_COLUMNS, str),
)
df.head()
# Out:
#    GlobalEventID       Day  MonthYear  Year  FractionDate Actor1Code  \
# 0     1291541985  20250228     202502  2025     2025.1589        CVL
# 1     1291541986  20250228     202502  2025     2025.1589        IRN
# 2     1291541987  20250228     202502  2025     2025.1589        IRN
# 3     1291541988  20250228     202502  2025     2025.1589        IRN
# 4     1291541989  20250228     202502  2025     2025.1589        ISR
#
#   Actor1Name Actor1CountryCode Actor1KnownGroupCode Actor1EthnicCode  ...  \
# 0  RESIDENTS               NaN                  NaN              NaN  ...
# 1       IRAN               IRN                  NaN              NaN  ...
# 2    IRANIAN               IRN                  NaN              NaN  ...
# 3    IRANIAN               IRN                  NaN              NaN  ...
# 4     ISRAEL               ISR                  NaN              NaN  ...
#
#   ActionGeo_Type                    ActionGeo_Fullname ActionGeo_CountryCode  \
# 0              3  Centralia, Washington, United States                    US
# 1              4                  Tehran, Tehran, Iran                    IR
# 2              1                                Israel                    IS
# 3              4          Ben Gurion, HaMerkaz, Israel                    IS
# 4              4                  Tehran, Tehran, Iran                    IR
#
#   ActionGeo_ADM1Code  ActionGeo_ADM2Code ActionGeo_Lat ActionGeo_Long  \
# 0               USWA               WA041       46.7162      -122.9540
# 1               IR26               41130       35.7500        51.5148
# 2                 IS                 NaN       31.5000        34.7500
# 3               IS02               18311       32.0114        34.8867
# 4               IR26               41130       35.7500        51.5148
#
#   ActionGeo_FeatureID       DATEADDED  \
# 0             1503899  20260228120000
# 1            10074674  20260228120000
# 2                  IS  20260228120000
# 3              149507  20260228120000
# 4            10074674  20260228120000
#
#                                            SOURCEURL
# 0  https://www.lmtribune.com/opinion/fix-tax-that...
# 1  https://www.thetimes.com/world/middle-east/isr...
# 2  https://www.thetimes.com/world/middle-east/isr...
# 3  https://www.clevelandjewishnews.com/jta/us-isr...
# 4  https://www.thetimes.com/world/middle-east/isr...
#
# [5 rows x 61 columns]
